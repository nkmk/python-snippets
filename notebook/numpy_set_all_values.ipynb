# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.26.1

# %%
a = np.arange(6).reshape(2, 3)
print(a)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
b = np.zeros_like(a)
print(b)
# Out:
# [[0 0 0]
#  [0 0 0]]

# %%
print(a)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
a[:, :] = 0
print(a)
# Out:
# [[0 0 0]
#  [0 0 0]]

# %%
a[:] = 1
print(a)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %%
print(a.dtype)
# Out:
# int64

# %%
a[:] = 0.123
print(a)
# Out:
# [[0 0 0]
#  [0 0 0]]

# %%
a = a.astype(np.float64)
a[:] = 0.123
print(a)
# Out:
# [[0.123 0.123 0.123]
#  [0.123 0.123 0.123]]
