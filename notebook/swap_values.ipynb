# %%
a = 1
b = 2

# %%
a, b = b, a

# %%
print(f'{a = }')
print(f'{b = }')
# Out:
# a = 2
# b = 1

# %%
a, b = 100, 200

# %%
print(f'{a = }')
print(f'{b = }')
# Out:
# a = 100
# b = 200

# %%
a, b, c, d = 0, 1, 2, 3

# %%
a, b, c, d = d, c, b, a

# %%
print(f'{a = }')
print(f'{b = }')
print(f'{c = }')
print(f'{d = }')
# Out:
# a = 3
# b = 2
# c = 1
# d = 0

# %%
l = [0, 1, 2, 3, 4]

# %%
l[0], l[3] = l[3], l[0]

# %%
print(l)
# Out:
# [3, 1, 2, 0, 4]

# %%
print(sorted(l))
# Out:
# [0, 1, 2, 3, 4]

# %%
print(sorted(l, reverse=True))
# Out:
# [4, 3, 2, 1, 0]
