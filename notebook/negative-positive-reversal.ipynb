# %%
import numpy as np
from PIL import Image

# %%
im = np.array(Image.open('data/src/horse.png').convert('RGB'))

# %% [markdown]
# ![horse](data/src/horse.png)

# %%
im_r = 255 - im

# %%
Image.fromarray(im_r).save('data/src/horse_r.png')

# %% [markdown]
# ![horse reverse](data/src/horse_r.png)
