# %%
import numpy as np

# %%
a = np.arange(6).reshape(2, 3)
print(a)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
print(a.max())
# Out:
# 5

# %%
print(a.max(axis=0))
# Out:
# [3 4 5]

# %%
print(a.max(axis=1))
# Out:
# [2 5]
