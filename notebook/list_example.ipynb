# %%
l = ['apple', 100, 0.123]
print(l)
# Out:
# ['apple', 100, 0.123]

# %%
l_2d = [[0, 1, 2], [3, 4, 5], [6, 7, 8]]
print(l_2d)
# Out:
# [[0, 1, 2], [3, 4, 5], [6, 7, 8]]

# %%
print(l_2d[1][1])
# Out:
# 4

# %%
l_num = [0, 10, 20, 30]

# %%
print(min(l_num))
# Out:
# 0

# %%
print(max(l_num))
# Out:
# 30

# %%
print(sum(l_num))
# Out:
# 60

# %%
print(sum(l_num) / len(l_num))
# Out:
# 15.0

# %%
l_str = ['apple', 'orange', 'banana']

# %%
for s in l_str:
    print(s)
# Out:
# apple
# orange
# banana
