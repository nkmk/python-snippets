# %%
q = 10 // 3
mod = 10 % 3
print(q, mod)
# Out:
# 3 1

# %%
q, mod = divmod(10, 3)
print(q, mod)
# Out:
# 3 1

# %%
answer = divmod(10, 3)
print(answer)
print(answer[0], answer[1])
# Out:
# (3, 1)
# 3 1
