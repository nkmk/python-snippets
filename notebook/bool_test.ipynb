# %%
print(bool('True'))
print(bool('False'))
print(bool('abc'))
# Out:
# True
# True
# True

# %%
print(bool(''))
# Out:
# False

# %%
print(bool(1))
print(bool(2))
print(bool(1.23))
print(bool(-1))
# Out:
# True
# True
# True
# True

# %%
print(bool(0))
print(bool(0.0))
print(bool(0j))
# Out:
# False
# False
# False

# %%
print(bool([1, 2, 3]))
print(bool((1, 2, 3)))
print(bool({1, 2, 3}))
print(bool({'k1': 1, 'k2':2, 'k3': 3}))
# Out:
# True
# True
# True
# True

# %%
print(bool([]))
print(bool(()))
print(bool({}))
# Out:
# False
# False
# False

# %%
print(bool(None))
# Out:
# False
